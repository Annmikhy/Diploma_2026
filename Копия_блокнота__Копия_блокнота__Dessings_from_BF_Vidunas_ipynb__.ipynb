# %%
import matplotlib.pyplot as plt #Активируем библиотеку для построения графиков
import numpy as np #Активируем библиотеку для численных списков

# %%
X_min = -1.004
X_max = -0.990
Y_min = -0.007
Y_max = 0.007
resolution = 1000
epsilon = 0.01
delta = 0.2 #shift of z if BF is not a polynomial
def beta(z): # Bely's function
    #return 1 - z ** 2
    #return -4 * z**2 * (z**2 -1)
    #return -4 * z**3 * (z**3 - 1)
    #return - (4 * z**2 - 1)**2 * (z**2 - 1)
    #return -4 * z**4 * (z - 1) * (z + 1) * (z**2 + 1)
    #return - (1024/729) * z**3 * (z - 1) * (16 * z**2 + 8 * z + 3) * (4 * z - 3)**2
    #return (z**2 - 1)**2/( -4 * z**2) # not a tree
    #return (((z**3 + 6 * z**2 + 180 * z - 900)*(z**3 - 3 * z**2 - 9 * z + 315)**2) / ( (108**2) * (3 * z - 5)**4)) # not a tree
    return ( ((27*z**2+11*((-0.43288)**2+5)*z+11*(1-4*(-0.43288)))**4*(z**3)) / ((11*(1-4*(-0.43288))*z**2+11*((-0.43288)**2+5)*z+27)**4)) # not a tree

# %%
#X_min = 0.8
#X_max = 1.0
#Y_min = 0.3
#Y_max = 0.5
resolution = 1000
epsilon = 0.000001
#delta = 0.001 #shift of z if BF is not a polynomial
def beta(z): # Bely's function
    #return 1 - z ** 2
    #return -4 * z**2 * (z**2 -1)
    #return -4 * z**3 * (z**3 - 1)
    #return - (4 * z**2 - 1)**2 * (z**2 - 1)
    #return -4 * z**4 * (z - 1) * (z + 1) * (z**2 + 1)
    #return - (1024/729) * z**3 * (z - 1) * (16 * z**2 + 8 * z + 3) * (4 * z - 3)**2
    #return (z**2 - 1)**2/( -4 * z**2) # not a tree
    #return (149587343098087735296*z**36 - 2692572175765579235328*z**35 + 28072558054741131657216*z**34 - 210220079500512630669312*z**33 + 1240588779304074143072256*z**32 - 6049489443589599082315776*z**31 + 25086260683848010659004416*z**30 - 90139727465471707057225728*z**29 + 852740060437343984521576448*z**28/3 - 2380973182024881033522970624*z**27/3 + 53307510629758729337889095680*z**26/27 - 118653317418949391720642510848*z**25/27 + 518236784581358819358602297344000*z**24/59049 - 310048878722604836124227849420800*z**23/19683 + 13513858940197266572294138361806848*z**22/531441 - 19624160957590245883743794980978688*z**21/531441 + 76884307295554776862068042588225536*z**20/1594323 - 90258446758137831832451885280788480*z**19/1594323 + 16866696298129238541697754329103618811136*z**18/282429536481 - 1776176713006543405020675365470091879680*z**17/31381059609 + 40841248155077737211946661402821410627584*z**16/847288609443 - 31264957120861659561324002798434237058048*z**15/847288609443 + 193709767340315323768648061705372670333184*z**14/7625597484987 - 119950615044610101711063389303563124022016*z**13/7625597484987 + 28050138095948624109491825215593331854791734127*z**12/3202018886335981248 - 2339675465038295643909701480665606903949792111*z**11/533669814389330208 + 56727279530249246399265022032659556415216501921*z**10/28818169977023831232 - 5696843339002054826473266916216941258972846305*z**9/7204542494255957808 + 73392065469240117949389293578783080120740171627*z**8/259363529793214481088 - 11626337812751020761514869364542561120146164201*z**7/129681764896607240544 + 827473018652420250474019705762179393371403652997*z**6/33198531813531453579264 - 199310379276681534721087277228271493185001681423*z**5/33198531813531453579264 + 367373914708022831786062188582073193525318995979*z**4/298786786321783082213376 - 62158665874284391143167060077767677903830431541*z**3/298786786321783082213376 + 8286143129507778704571255950135113549028878091*z**2/298786786321783082213376 - 29375314040824726407568656844890191293653509*z/11066177271177151193088 + 202463279129038346813373560019733061377388515895/1376809511370776442839236608)/149587343098087735296

# %%
X_min = -15.0
X_max = 17.0
Y_min = -15.5
Y_max = 15.5
#
#X_min = 0.8
#X_max = 1.0
#Y_min = 0.3
#Y_max = 0.5
resolution = 5000
epsilon = 0.000001
#delta = 0.001 #shift of z if BF is not a polynomial
def beta(z): # Bely's function
    #return 1 - z ** 2
    #return -4 * z**2 * (z**2 -1)
    #return -4 * z**3 * (z**3 - 1)
    #return - (4 * z**2 - 1)**2 * (z**2 - 1)
    #return -4 * z**4 * (z - 1) * (z + 1) * (z**2 + 1)
    #return - (1024/729) * z**3 * (z - 1) * (16 * z**2 + 8 * z + 3) * (4 * z - 3)**2
    #return (z**2 - 1)**2/( -4 * z**2) # not a tree
    #return (149587343098087735296*z**36 - 2692572175765579235328*z**35 + 28072558054741131657216*z**34 - 210220079500512630669312*z**33 + 1240588779304074143072256*z**32 - 6049489443589599082315776*z**31 + 25086260683848010659004416*z**30 - 90139727465471707057225728*z**29 + 852740060437343984521576448*z**28/3 - 2380973182024881033522970624*z**27/3 + 53307510629758729337889095680*z**26/27 - 118653317418949391720642510848*z**25/27 + 518236784581358819358602297344000*z**24/59049 - 310048878722604836124227849420800*z**23/19683 + 13513858940197266572294138361806848*z**22/531441 - 19624160957590245883743794980978688*z**21/531441 + 76884307295554776862068042588225536*z**20/1594323 - 90258446758137831832451885280788480*z**19/1594323 + 16866696298129238541697754329103618811136*z**18/282429536481 - 1776176713006543405020675365470091879680*z**17/31381059609 + 40841248155077737211946661402821410627584*z**16/847288609443 - 31264957120861659561324002798434237058048*z**15/847288609443 + 193709767340315323768648061705372670333184*z**14/7625597484987 - 119950615044610101711063389303563124022016*z**13/7625597484987 + 28050138095948624109491825215593331854791734127*z**12/3202018886335981248 - 2339675465038295643909701480665606903949792111*z**11/533669814389330208 + 56727279530249246399265022032659556415216501921*z**10/28818169977023831232 - 5696843339002054826473266916216941258972846305*z**9/7204542494255957808 + 73392065469240117949389293578783080120740171627*z**8/259363529793214481088 - 11626337812751020761514869364542561120146164201*z**7/129681764896607240544 + 827473018652420250474019705762179393371403652997*z**6/33198531813531453579264 - 199310379276681534721087277228271493185001681423*z**5/33198531813531453579264 + 367373914708022831786062188582073193525318995979*z**4/298786786321783082213376 - 62158665874284391143167060077767677903830431541*z**3/298786786321783082213376 + 8286143129507778704571255950135113549028878091*z**2/298786786321783082213376 - 29375314040824726407568656844890191293653509*z/11066177271177151193088 + 202463279129038346813373560019733061377388515895/1376809511370776442839236608)/149587343098087735296
    return ((((((((((((((((((((((((((((((((((((149587343098087735296*z - 2692572175765579235328)*z + 28072558054741131657216)*z - 210220079500512630669312)*z + 1240588779304074143072256)*z - 6049489443589599082315776)*z + 25086260683848010659004416)*z - 90139727465471707057225728)*z + (852740060437343984521576448/3))*z - (2380973182024881033522970624/3))*z + (53307510629758729337889095680/27))*z - (118653317418949391720642510848/27))*z+ (518236784581358819358602297344000/59049))*z - (310048878722604836124227849420800/19683))*z + (13513858940197266572294138361806848/531441))*z - (19624160957590245883743794980978688/531441))*z + (76884307295554776862068042588225536/1594323))*z - (90258446758137831832451885280788480/1594323))*z + (16866696298129238541697754329103618811136/282429536481))*z - (1776176713006543405020675365470091879680/31381059609))*z + (40841248155077737211946661402821410627584/847288609443))*z - (31264957120861659561324002798434237058048/847288609443))*z + (193709767340315323768648061705372670333184/7625597484987))*z - (119950615044610101711063389303563124022016/7625597484987))*z + (28050138095948624109491825215593331854791734127/3202018886335981248))*z - (2339675465038295643909701480665606903949792111/533669814389330208))*z + (56727279530249246399265022032659556415216501921/28818169977023831232))*z - (5696843339002054826473266916216941258972846305/7204542494255957808))*z + (73392065469240117949389293578783080120740171627/259363529793214481088))*z - (11626337812751020761514869364542561120146164201/129681764896607240544))*z + (827473018652420250474019705762179393371403652997/33198531813531453579264))*z - (199310379276681534721087277228271493185001681423/33198531813531453579264))*z + (367373914708022831786062188582073193525318995979/298786786321783082213376))*z - (62158665874284391143167060077767677903830431541/298786786321783082213376))*z + (8286143129507778704571255950135113549028878091/298786786321783082213376))*z - (29375314040824726407568656844890191293653509/11066177271177151193088))*z + 202463279129038346813373560019733061377388515895/1376809511370776442839236608)/149587343098087735296

# %%
# @title Текст заголовка по умолчанию
a = np.array([])
b = np.array([])
a1 = np.array([])
b1 = np.array([])
z = complex(0, 0)
B = complex(0, 0)
for x in range(resolution):
    for y in range(resolution):
        z = complex(X_min + x * (X_max - X_min)/resolution, Y_min + y * (Y_max - Y_min)/resolution)
        if ( 0.001 < abs(z + 1.00458)) and  ( 0.001 < abs(z + 0.894504)):
        #if ( 0.1 < abs(z - 5/3)):
           B = beta(z)# set beta(z-delta) if BF is not a polynomial
           if -epsilon <= B.imag <= epsilon and 0 <= B.real <=  1:
           #if -0.00001-0.03* (((54)**2)/4 - B.real) <= B.imag <= 0.00001+0.03* (((54)**2)/4 - B.real) and 0 <= B.real <= ((54)**2)/4:
           #if -0.001 <= B.imag <= 0.001 and 0 <= B.real <= ((54)**2)/4:
           #if -0.00001-0.03* (B.real) <= B.imag <= 0.00001+0.03* (B.real) and 0 <= B.real <= (6375413848263518710318586101791961251782012530503577767680233/16677181699666569):
              a1 = np.append(a1[:], z.real)
              b1 = np.append(b1[:], z.imag)

        #if -epsilon <= B.imag <= epsilon and  -4192754310295766562566960865854641202837986322785231146339328382390071787776/4710128697246244834921603689 <= B.real <=  0:
        #if -0.00001-0.03* (-B.real) <= B.imag <= 0.00001+0.03* (-B.real) and  -939056055962623357306073125714641590.6068057050198981 <= B.real <= 0:
#            a = np.append(a[:], B.real)
#            b = np.append(b[:], B.imag)
         #   a = np.append(a[:], z.real)
         #   b = np.append(b[:], z.imag)
#print(a, b)

# %%
fig, axs = plt.subplots()
axs.axis((X_min, X_max, Y_min, Y_max))# Размер области
axs.set_xlabel('real')  # Называем переменную абсцис
axs.set_ylabel('imag')  # Называем переменную ординаты
axs.set_title("")  # Даём название графику
axs.grid(True) # Чертим сетку для удобства
#axs.scatter(a, b,s=1,c="g") # Ставим точки из списка
axs.scatter(a1, b1,s=1,c="r") # Ставим точки из списка
plt.show()

# %%
# @title Текст заголовка по умолчанию
a = np.array([])
b = np.array([])
a1 = np.array([])
b1 = np.array([])
z = complex(0, 0)
B = complex(0, 0)
for x in range(resolution):
    for y in range(resolution):
        z = complex(X_min + x * (X_max - X_min)/resolution, Y_min + y * (Y_max - Y_min)/resolution)
        if ( 0.01 < abs(z)) and  ( 0.2 < abs(z + 5/4)):
           B = beta(z)# set beta(z-delta) if BF is not a polynomial
           #if -epsilon <= B.imag <= epsilon and 0 <= B.real <=  1/4:
           if -0.00001-0.03* (((54)**2)/4 - B.real) <= B.imag <= 0.00001+0.03* (((54)**2)/4 - B.real) and 0 <= B.real <= ((54)**2)/4:
           #if -0.001 <= B.imag <= 0.001 and 0 <= B.real <= ((54)**2)/4:
           #if -0.00001-0.03* (B.real) <= B.imag <= 0.00001+0.03* (B.real) and 0 <= B.real <= (6375413848263518710318586101791961251782012530503577767680233/16677181699666569):
              a1 = np.append(a1[:], z.real)
              b1 = np.append(b1[:], z.imag)

        #if -epsilon <= B.imag <= epsilon and  -4192754310295766562566960865854641202837986322785231146339328382390071787776/4710128697246244834921603689 <= B.real <=  0:
        #if -0.00001-0.03* (-B.real) <= B.imag <= 0.00001+0.03* (-B.real) and  -939056055962623357306073125714641590.6068057050198981 <= B.real <= 0:
#            a = np.append(a[:], B.real)
#            b = np.append(b[:], B.imag)
         #   a = np.append(a[:], z.real)
         #   b = np.append(b[:], z.imag)
#print(a, b)
